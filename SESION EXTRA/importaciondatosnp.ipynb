# %%
import numpy as np

# %%
ruta = "C:/DSPython/medallas_import_numpy.csv"

# %%
array = np.genfromtxt(ruta)
array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 array = np.genfromtxt()
#       2 array
#
# TypeError: genfromtxt() missing 1 required positional argument: 'fname'

# %%
array = np.genfromtxt(ruta, delimiter=',')
array
# Out:
# array([[ nan,  nan,  nan,  nan,  nan],
#        [ nan,   1.,   2.,   3.,  nan],
#        [ nan,   2.,   2.,   4.,  nan],
#        [ 17.,   7.,  22.,  46.,  nan],
#        [  1.,   1.,   5.,   7.,  nan],
#        [ nan,   3.,   4.,   7.,  nan],
#        [  2.,  nan,  nan,   2.,  nan],
#        [ nan,   1.,  nan,   1.,  nan],
#        [  1.,   3.,   3.,   7.,  nan],
#        [  3.,   1.,   3.,   7.,  nan],
#        [  1.,  nan,  nan,   1.,  nan],
#        [ nan,  nan,   1.,   1.,  nan],
#        [  7.,   6.,   8.,  21.,  nan],
#        [  3.,   1.,   2.,   6.,  nan],
#        [ nan,  nan,   1.,   1.,  nan],
#        [  7.,   6.,  11.,  24.,  nan],
#        [  2.,   4.,   6.,  12.,  nan],
#        [ nan,   4.,   1.,   5.,  nan],
#        [  3.,   3.,   2.,   8.,  nan],
#        [ nan,  nan,   1.,   1.,  nan],
#        [  7.,   3.,   5.,  15.,  nan],
#        [  4.,   4.,   3.,  11.,  nan],
#        [  3.,   4.,   4.,  11.,  nan],
#        [ nan,   3.,   2.,   5.,  nan],
# ...

# %%
array = np.genfromtxt(ruta, delimiter=',', filling_values=0)
array
# Out:
# array([[  0.,   0.,   0.,   0.,   0.],
#        [  0.,   1.,   2.,   3.,   0.],
#        [  0.,   2.,   2.,   4.,   0.],
#        [ 17.,   7.,  22.,  46.,   0.],
#        [  1.,   1.,   5.,   7.,   0.],
#        [  0.,   3.,   4.,   7.,   0.],
#        [  2.,   0.,   0.,   2.,   0.],
#        [  0.,   1.,   0.,   1.,   0.],
#        [  1.,   3.,   3.,   7.,   0.],
#        [  3.,   1.,   3.,   7.,   0.],
#        [  1.,   0.,   0.,   1.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   6.,   8.,  21.,   0.],
#        [  3.,   1.,   2.,   6.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   6.,  11.,  24.,   0.],
#        [  2.,   4.,   6.,  12.,   0.],
#        [  0.,   4.,   1.,   5.,   0.],
#        [  3.,   3.,   2.,   8.,   0.],
#        [  0.,   0.,   1.,   1.,   0.],
#        [  7.,   3.,   5.,  15.,   0.],
#        [  4.,   4.,   3.,  11.,   0.],
#        [  3.,   4.,   4.,  11.,   0.],
#        [  0.,   3.,   2.,   5.,   0.],
# ...

# %%
array = np.genfromtxt(ruta, delimiter=',', filling_values=0, dtype=int)
array
# Out:
# array([[  0,   0,   0,   0,   0],
#        [  0,   1,   2,   3,   0],
#        [  0,   2,   2,   4,   0],
#        [ 17,   7,  22,  46,   0],
#        [  1,   1,   5,   7,   0],
#        [  0,   3,   4,   7,   0],
#        [  2,   0,   0,   2,   0],
#        [  0,   1,   0,   1,   0],
#        [  1,   3,   3,   7,   0],
#        [  3,   1,   3,   7,   0],
#        [  1,   0,   0,   1,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,   8,  21,   0],
#        [  3,   1,   2,   6,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,  11,  24,   0],
#        [  2,   4,   6,  12,   0],
#        [  0,   4,   1,   5,   0],
#        [  3,   3,   2,   8,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   3,   5,  15,   0],
#        [  4,   4,   3,  11,   0],
#        [  3,   4,   4,  11,   0],
#        [  0,   3,   2,   5,   0],
#        [  2,   1,   0,   3,   0],
#        [  1,   1,   4,   6,   0],
#        [ 39,  41,  33, 113,   0],
# ...

# %%
array = np.genfromtxt(ruta, delimiter=',', filling_values=0, dtype=int, skip_header=1)
array
# Out:
# array([[  0,   1,   2,   3,   0],
#        [  0,   2,   2,   4,   0],
#        [ 17,   7,  22,  46,   0],
#        [  1,   1,   5,   7,   0],
#        [  0,   3,   4,   7,   0],
#        [  2,   0,   0,   2,   0],
#        [  0,   1,   0,   1,   0],
#        [  1,   3,   3,   7,   0],
#        [  3,   1,   3,   7,   0],
#        [  1,   0,   0,   1,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,   8,  21,   0],
#        [  3,   1,   2,   6,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   6,  11,  24,   0],
#        [  2,   4,   6,  12,   0],
#        [  0,   4,   1,   5,   0],
#        [  3,   3,   2,   8,   0],
#        [  0,   0,   1,   1,   0],
#        [  7,   3,   5,  15,   0],
#        [  4,   4,   3,  11,   0],
#        [  3,   4,   4,  11,   0],
#        [  0,   3,   2,   5,   0],
#        [  2,   1,   0,   3,   0],
#        [  1,   1,   4,   6,   0],
#        [ 39,  41,  33, 113,   0],
#        [  1,   0,   1,   2,   0],
# ...

# %%
array_export = np.array([[1, 2, 3],
                         [4, 5, 6]])

# %%
ruta_arreglo = "C:/DSPython/array_export.csv"

# %%
np.savetxt(ruta_arreglo, array_export, delimiter=',')

# %%
np.savetxt(ruta_arreglo, array_export, delimiter=',', fmt="%d")
