# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
import numpy as np

# %%
fig = plt.figure()
axs = plt.axes()

# %%
plt.grid()

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [1, 2, 3, 4, 5, 6, 7]

# %%
plt.plot(x, y)
plt.grid()

# %%
plt.plot(x, y, "bo-")
plt.grid()

# %%
plt.plot(x, y, "ro-")
plt.axis([0, 8, 0, 8])
plt.grid()

# %%
ruta = "C:/DSPython/D1Top-Películas_c.csv"
df = pd.read_csv(ruta)
df
# Out:
#    indice_global  indice_estricto                    título  \
# 0              0                0  The Shawshank Redemption
# 1              1                1             The Godfather
# 2              2                1             The Godfather
# 3              3                2           The Dark Knight
# 4              4                2           The Dark Knight
# 5              5                2           The Dark Knight
# 6              6                3          Schindler's List
# 7              7                3          Schindler's List
# 8              8                3          Schindler's List
#
#                director   año  duración     género  rating  metascore  \
# 0        Frank Darabont  1994       142      Drama     9.3         82
# 1  Francis Ford Coppola  1972       175     Crimen     9.2        100
# 2  Francis Ford Coppola  1972       175      Drama     9.2        100
# 3     Christopher Nolan  2008       152     Acción     9.0         84
# ...

# %%
plt.plot(df["título"], df["rating"], "ro-")
plt.xticks(rotation=45)
plt.grid();

# %%
plt.xticks(rotation=45)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
db = sqlite3.connect("INCEPERU")

# %%
cursor = db.cursor()

# %%
cursor.execute("""
CREATE TABLE usuarios(
    id INTEGER,
    nombre TEXT,
    edad INTEGER,
    numero TEXT
""")

db.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 cursor.execute("""
#       2 CREATE TABLE usuarios(
#       3     id INTEGER,
#       4     nombre TEXT,
#       5     edad INTEGER,
#       6     numero TEXT
#       7 """)
#       9 db.commit()
#
# OperationalError: table usuarios already exists

# %%
cursor.execute("INSERT INTO usuarios(nombre, edad) VALUES (?, ?)", ("Juanita", 40))
cursor.execute("INSERT INTO usuarios(nombre, edad) VALUES (?, ?)", ("Pedro", 70))
cursor.execute("INSERT INTO usuarios(nombre, edad) VALUES (?, ?)", ("Carlos", 20))

conexion.commit()

# %%
cursor.execute("SELECT * FROM usuarios")
usuarios = cursor.fetchall()

for usuario in usuarios:
    print(usuario)
# Out:
# (None, 'Juanita', 40)
# (None, 'Pedro', 70)
# (None, 'Carlos', 20)

# %%
df = pd.read_sql_query("SELECT * FROM usuarios", db)
df
# Out:
#      id   nombre  edad
# 0  None  Juanita    40
# 1  None    Pedro    70
# 2  None   Carlos    20

# %%
nombres = df["edad"].to_numpy()
nombres
# Out:
# array([40, 70, 20], dtype=int64)

# %%
plt.plot(df["nombre"], df["edad"])
plt.xticks(rotation=45)
plt.grid();
