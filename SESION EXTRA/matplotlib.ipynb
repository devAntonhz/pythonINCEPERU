# %%
import matplotlib.pyplot as plt

# %%
numeros = [4, 5, 1, 3, 7]

# %%
numeros
# Out:
# [4, 5, 1, 3, 7]

# %%
# plt.plot(numeros)
# plt.show()

# %%
plt.plot(numeros);

# %%
plt.plot(numeros)
plt.savefig("C:/DSPython/mi_grafica.png")
